# %%
import pandas as pd

# %%
pokemon = pd.read_csv('file.csv')

# %%
pokemon.info()   #gives basic info about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          799 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.6+ KB

# %%
pokemon.head()    #default is 5 rows
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
pokemon.dtypes.index
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
pokemon.describe()   #gives basic statistics
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
pokemon.describe(include=['O']) #to include categorical data
# Out:
#           Name Type 1  Type 2
# count      799    800     414
# unique     799     18      18
# top     Bonsly  Water  Flying
# freq         1    112      97

# %%
pokemon.shape[0]    #shape gives total number of rows
# Out:
# 800

# %%
#to find % of missing values
100 *pokemon.isna().sum() / pokemon.shape[0]
# Out:
# #              0.000
# Name           0.125
# Type 1         0.000
# Type 2        48.250
# HP             0.000
# Attack         0.000
# Defense        0.000
# Sp. Atk        0.000
# Sp. Def        0.000
# Speed          0.000
# Generation     0.000
# Legendary      0.000
# dtype: float64

# %%
pokemon.dropna(axis=0)  #axis = 0 removes rows which have NA. axis = 1 will remove columns which have NA
# Out:
#        #                    Name    Type 1  Type 2   HP  Attack  Defense  \
# 0      1               Bulbasaur     Grass  Poison   45      49       49
# 1      2                 Ivysaur     Grass  Poison   60      62       63
# 2      3                Venusaur     Grass  Poison   80      82       83
# 3      4           Mega Venusaur     Grass  Poison   80     100      123
# 6      7               Charizard      Fire  Flying   78      84       78
# 7      8        Mega Charizard X      Fire  Dragon   78     130      111
# 8      9        Mega Charizard Y      Fire  Flying   78     104       78
# 15    16              Butterfree       Bug  Flying   60      45       50
# 16    17                  Weedle       Bug  Poison   40      35       30
# 17    18                  Kakuna       Bug  Poison   45      25       50
# 18    19                Beedrill       Bug  Poison   65      90       40
# 19    20           Mega Beedrill       Bug  Poison   65     150       40
# ...

# %%
pokemon.drop('#',inplace=True,axis=1)

# %%
pokemon
# Out:
#                        Name    Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0                 Bulbasaur     Grass  Poison   45      49       49       65
# 1                   Ivysaur     Grass  Poison   60      62       63       80
# 2                  Venusaur     Grass  Poison   80      82       83      100
# 3             Mega Venusaur     Grass  Poison   80     100      123      122
# 4                Charmander      Fire     NaN   39      52       43       60
# 5                Charmeleon      Fire     NaN   58      64       58       80
# 6                 Charizard      Fire  Flying   78      84       78      109
# 7          Mega Charizard X      Fire  Dragon   78     130      111      130
# 8          Mega Charizard Y      Fire  Flying   78     104       78      159
# 9                  Squirtle     Water     NaN   44      48       65       50
# 10                Wartortle     Water     NaN   59      63       80       65
# ...

# %%
#difference between idxmax() and argmax()
pokemon.set_index('Name').Defense.idxmax()
# Out:
# 'Mega Steelix'

# %%
highest_lengendary = pokemon[pokemon['Legendary']==True]['Type 1'].value_counts().idxmax()
highest_lengendary
# Out:
# 'Psychic'

# %%
#result = (pokemon['Type 2'].isnull()) and (pokemon['Legendary']==True)
#result
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-b2f255ab506e> in <module>()
# ----> 1 result = (pokemon['Type 2'].isnull()) and (pokemon['Legendary']==True)
#       2 result
#
# ~\anaconda\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1119         raise ValueError("The truth value of a {0} is ambiguous. "
#    1120                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1121                          .format(self.__class__.__name__))
#    1122
#    1123     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
bank = pd.read_csv('bank.csv')

# %%
bank.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
pokemon.groupby(['Legendary','Generation']).value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-366d7c18f8dc> in <module>()
# ----> 1 pokemon.groupby(['Legendary','Generation']).value_counts()
#
# ~\anaconda\lib\site-packages\pandas\core\groupby.py in __getattr__(self, attr)
#     674
#     675         raise AttributeError("%r object has no attribute %r" %
# --> 676                              (type(self).__name__, attr))
#     677
#     678     plot = property(GroupByPlot)
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'value_counts'

# %%
pokemon.head(25)
# Out:
#      #              Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1         Bulbasaur   Grass  Poison  45      49       49       65
# 1    2           Ivysaur   Grass  Poison  60      62       63       80
# 2    3          Venusaur   Grass  Poison  80      82       83      100
# 3    4     Mega Venusaur   Grass  Poison  80     100      123      122
# 4    5        Charmander    Fire     NaN  39      52       43       60
# 5    6        Charmeleon    Fire     NaN  58      64       58       80
# 6    7         Charizard    Fire  Flying  78      84       78      109
# 7    8  Mega Charizard X    Fire  Dragon  78     130      111      130
# 8    9  Mega Charizard Y    Fire  Flying  78     104       78      159
# 9   10          Squirtle   Water     NaN  44      48       65       50
# 10  11         Wartortle   Water     NaN  59      63       80       65
# 11  12         Blastoise   Water     NaN  79      83      100       85
# ...

# %%
pokemon
# Out:
#        #                    Name    Type 1  Type 2   HP  Attack  Defense  \
# 0      1               Bulbasaur     Grass  Poison   45      49       49
# 1      2                 Ivysaur     Grass  Poison   60      62       63
# 2      3                Venusaur     Grass  Poison   80      82       83
# 3      4           Mega Venusaur     Grass  Poison   80     100      123
# 4      5              Charmander      Fire     NaN   39      52       43
# 5      6              Charmeleon      Fire     NaN   58      64       58
# 6      7               Charizard      Fire  Flying   78      84       78
# 7      8        Mega Charizard X      Fire  Dragon   78     130      111
# 8      9        Mega Charizard Y      Fire  Flying   78     104       78
# 9     10                Squirtle     Water     NaN   44      48       65
# 10    11               Wartortle     Water     NaN   59      63       80
# 11    12               Blastoise     Water     NaN   79      83      100
# ...

# %%
pokemon.Attack.mean()
# Out:
# 79.00125

# %%
dragon = pokemon[pokemon['Type 1']=='Dragon']
dragon
# Out:
#        #                 Name  Type 1    Type 2   HP  Attack  Defense  \
# 159  160              Dratini  Dragon       NaN   41      64       45
# 160  161            Dragonair  Dragon       NaN   61      84       65
# 161  162            Dragonite  Dragon    Flying   91     134       95
# 365  366              Altaria  Dragon    Flying   75      70       90
# 366  367         Mega Altaria  Dragon     Fairy   75     110      110
# 406  407                Bagon  Dragon       NaN   45      75       60
# 407  408              Shelgon  Dragon       NaN   65      95      100
# 408  409            Salamence  Dragon    Flying   95     135       80
# 409  410       Mega Salamence  Dragon    Flying   95     145      130
# 417  418               Latias  Dragon   Psychic   80      80       90
# 418  419          Mega Latias  Dragon   Psychic   80     100      120
# 419  420               Latios  Dragon   Psychic   80      90       80
# ...

# %%
import matplotlib.pyplot as plt
mean_attack =pokemon.Attack.mean()
dragon =pokemon[pokemon['Type 1']=='Dragon']
mean_dragon = dragon.mean()
mean_dragon
# Out:
# #             522.84375
# HP             83.31250
# Attack        112.12500
# Defense        86.37500
# Sp. Atk        96.84375
# Sp. Def        88.84375
# Speed          83.03125
# Generation      3.87500
# Legendary       0.37500
# dtype: float64

# %%
fig, (ax_1, ax_2) = plt.subplots(1,2, figsize=(20,10))
res = pokemon.groupby(['Generation', 'Legendary']).size().unstack()
res.plot(kind='bar', stacked=True, ax=ax_1)
# Stacked bar-chart representing percentages
new_res = res.fillna(0)

# %%
# Out:
# Legendary   False  True
# Generation
# 1             160      6
# 2             101      5
# 3             142     18
# 4             108     13
# 5             150     15
# 6              74      8 Legendary   False  True
# Generation
# 1             160      6
# 2             101      5
# 3             142     18
# 4             108     13
# 5             150     15
# 6              74      8
